# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %% [markdown]
# ### removing unwanted columns

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %% [markdown]
# # Column names and descriptions

# %% [markdown]
# - Company-Name of the laptop brand
# - TypeName-Type of laptop
# - Inches-Screen size of laptop
# - ScreenResolution- Information about the laptop resolution,panel and this column also tells is weather the laptop is touch screen or not
# - Cpu-which processor(cpu) is used inside a laptop
# - Ram-ram size in the gb
# - Memory- Storage size and type of laptop
# - Gpu-Type Graphic card(Gpu) used in laptop
# - OpSys-oprating system of the laptop
# - Weight-weight of the laptop
# - Price-cost of the laptop

# %%
df.describe()
# Out:
#             Inches          Price
# count  1303.000000    1303.000000
# mean     15.017191   59870.042910
# std       1.426304   37243.201786
# min      10.100000    9270.720000
# 25%      14.000000   31914.720000
# 50%      15.600000   52054.560000
# 75%      15.600000   79274.246400
# max      18.400000  324954.720000

# %% [markdown]
# ## Let us now try to bring some insights out the available data

# %%
df["Company"].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### As we can see this is grapht of company and price where we can clearly see that Razer has the most expensive laptop and  vero has cheapest laptop.

# %%
df["TypeName"].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### As we can see this is grapht of Type of laptop and price where we can clearly see that workstation laptops are quite expensive laptops as compare to the other type of lapotops.

# %%
df["Inches"].value_counts()
# Out:
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: Inches, dtype: int64

# %%
sns.countplot(x=df['Inches'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### This graph clearly shows that most of the company preferred  15.6 inch screen

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
plt.show()

# %% [markdown]
# ### As you can see that with the increasing screen size price of the laptop is also increasing

# %%
df["ScreenResolution"].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %% [markdown]
# #### ScreenResolution column of this data set contain 3 type of information about the screen 1st is information about type of panel,2nd type of information tells us wheather the screen is touchscreen or not, 3rd provide the information about the no of pixels in X and Y axis.

# %% [markdown]
# #### So I created 4 new column to save the information separately

# %%
def ips(a):
    if "IPS" in a:
        return 1
    else:
        return 0
def touch(a):
    if "Touchscreen" in a:
        return 1
    else:
        return 0

# %%
df["IPS Panel"]=df["ScreenResolution"].map(ips)

# %% [markdown]
# #### This is the first new column which gives information wheather the panel is Ips or not.

# %%
df["Touchscreen"]=df["ScreenResolution"].map(touch)

# %% [markdown]
# #### This is the second new column which gives information wheather the screen is tounchscreen or not.

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  IPS Panel  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832          1
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232          0
# ...

# %%
sns.barplot(x=df['Touchscreen'],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### From this graph we can conclude that laptop with touchscreen are expensive than a normal laptop.

# %%
sns.barplot(x=df['IPS Panel'],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### From this graph we can conclude that laptop with IPS panels are expensive than a normal laptop.

# %%
def res(a):
    l=a.split(" ")
    return l[-1]

# %%
df["ScreenResolution"]=df["ScreenResolution"].map(res)

# %%
df.head()
# Out:
#   Company   TypeName  Inches ScreenResolution                         Cpu  \
# 0   Apple  Ultrabook    13.3        2560x1600        Intel Core i5 2.3GHz
# 1   Apple  Ultrabook    13.3         1440x900        Intel Core i5 1.8GHz
# 2      HP   Notebook    15.6        1920x1080  Intel Core i5 7200U 2.5GHz
# 3   Apple  Ultrabook    15.4        2880x1800        Intel Core i7 2.7GHz
# 4   Apple  Ultrabook    13.3        2560x1600        Intel Core i5 3.1GHz
#
#     Ram               Memory                           Gpu  OpSys  Weight  \
# 0   8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1   8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2   8GB            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3  16GB            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4   8GB            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price  IPS Panel  Touchscreen
# ...

# %%
df["ScreenResolution"].value_counts()
# Out:
# 1920x1080    841
# 1366x768     308
# 3840x2160     43
# 3200x1800     27
# 2560x1440     23
# 1600x900      23
# 2560x1600      6
# 2304x1440      6
# 2256x1504      6
# 1920x1200      5
# 1440x900       4
# 2880x1800      4
# 2400x1600      4
# 2160x1440      2
# 2736x1824      1
# Name: ScreenResolution, dtype: int64

# %%
def xpixals(a):
    a=a.split("x")
    x=int(a[0])
    return x
def ypixals(a):
    a=a.split("x")
    y=int(a[1])
    return y

# %%
df["Xres"]=df["ScreenResolution"].map(xpixals)
df["Yres"]=df["ScreenResolution"].map(ypixals)

# %% [markdown]
# #### Then I stored no of pixels in x and y axis separately

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
#  11  IPS Panel         1303 non-null   int64
#  12  Touchscreen       1303 non-null   int64
#  13  Xres              1303 non-null   int64
#  14  Yres              1303 non-null   int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 152.8+ KB

# %%
df.drop("ScreenResolution",axis=1,inplace=True)

# %%
sns.scatterplot(x=df['Xres'],y=df['Price'],hue=df["Touchscreen"])
plt.show()

# %%
sns.barplot(x=df['Xres'],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### From above two graphs we can clearly see that no of pixels are directly proportional to the price,It means with increasing no of pixels price of laptop also increases

# %% [markdown]
# #### While searching about the domain knowleadge of the project I got introduce with the below formula known as PPI(Pixel per inches). This single column contain the information about the three columns of my dataframe and it also increased my model accuracy by 4%

# %%
df["PPI"]=np.sqrt((df["Xres"]**2)+(df["Yres"]**2))/df["Inches"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Inches       1303 non-null   float64
#  3   Cpu          1303 non-null   object
#  4   Ram          1303 non-null   object
#  5   Memory       1303 non-null   object
#  6   Gpu          1303 non-null   object
#  7   OpSys        1303 non-null   object
#  8   Weight       1303 non-null   object
#  9   Price        1303 non-null   float64
#  10  IPS Panel    1303 non-null   int64
#  11  Touchscreen  1303 non-null   int64
#  12  Xres         1303 non-null   int64
#  13  Yres         1303 non-null   int64
#  14  PPI          1303 non-null   float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 152.8+ KB

# %%
df.drop(["Xres","Yres","Inches"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Cpu          1303 non-null   object
#  3   Ram          1303 non-null   object
#  4   Memory       1303 non-null   object
#  5   Gpu          1303 non-null   object
#  6   OpSys        1303 non-null   object
#  7   Weight       1303 non-null   object
#  8   Price        1303 non-null   float64
#  9   IPS Panel    1303 non-null   int64
#  10  Touchscreen  1303 non-null   int64
#  11  PPI          1303 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 122.3+ KB

# %%
df
# Out:
#      Company            TypeName                                   Cpu   Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz   8GB
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz   8GB
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz   8GB
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz  16GB
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz   8GB
# ...      ...                 ...                                   ...   ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   4GB
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz  16GB
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz   6GB
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
# ...

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu   Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  IPS Panel  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832          1
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232          0
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000          0
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360          1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080          1
#
#    Touchscreen         PPI
# 0            0  226.983005
# ...

# %%
sns.scatterplot(x=df['PPI'],y=df['Price'],hue=df["Touchscreen"])
plt.show()

# %% [markdown]
# #### From above two graphs we can clearly see that PPI are directly proportional to the price,It means with increasing no PPI price of laptop also increases

# %% [markdown]
# ### Changing data type of ram and weight column as those are numeric quantities and was given in object form

# %%
df["Ram"]=df["Ram"].str.replace("GB","")

# %%
df["Weight"]=df["Weight"].str.replace("kg","")

# %%
df["Ram"]=df["Ram"].astype("int64")

# %%
df["Weight"]=df["Weight"].astype("float64")

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  IPS Panel  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832          1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232          0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000          0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360          1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080          1
#
#    Touchscreen         PPI
# 0            0  226.983005
# 1            0  127.677940
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Above graph conclude that most of the company preferred 8 gb of Ram

# %%
sns.scatterplot(x=df['Ram'],y=df['Price'])
plt.show()

# %% [markdown]
# ### Size of the Ram also increase overall price of the laptop

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
plt.show()

# %% [markdown]
# #### As price increases laptop contain more and more hardware which also increase overall weight of the laptop

# %%
a=dict(df["Cpu"].value_counts())

# %%
print(a)
# Out:
# {'Intel Core i5 7200U 2.5GHz': 190, 'Intel Core i7 7700HQ 2.8GHz': 146, 'Intel Core i7 7500U 2.7GHz': 134, 'Intel Core i7 8550U 1.8GHz': 73, 'Intel Core i5 8250U 1.6GHz': 72, 'Intel Core i5 6200U 2.3GHz': 68, 'Intel Core i3 6006U 2GHz': 64, 'Intel Core i7 6500U 2.5GHz': 49, 'Intel Core i7 6700HQ 2.6GHz': 43, 'Intel Core i3 7100U 2.4GHz': 37, 'Intel Core i5 7300HQ 2.5GHz': 33, 'Intel Celeron Dual Core N3350 1.1GHz': 30, 'Intel Celeron Dual Core N3060 1.6GHz': 28, 'Intel Core i7 6600U 2.6GHz': 18, 'Intel Core i3 6006U 2.0GHz': 16, 'Intel Pentium Quad Core N4200 1.1GHz': 14, 'Intel Core i5 7300U 2.6GHz': 14, 'Intel Core i7 7600U 2.8GHz': 13, 'Intel Pentium Quad Core N3710 1.6GHz': 11, 'AMD A9-Series 9420 3GHz': 11, 'Intel Core i5 6300U 2.4GHz': 11, 'Intel Celeron Dual Core N3050 1.6GHz': 11, 'Intel Core i7 6820HK 2.7GHz': 10, 'Intel Core i3 6100U 2.3GHz': 9, 'Intel Core i3 7130U 2.7GHz': 8, 'Intel Core i7 6820HQ 2.7GHz': 7, 'Intel Core i5 6300HQ 2.3GHz': 7, 'Intel Core i7 7820HK 2.9GHz'
# ...

# %%
def cpus(a):
    if "Intel Core i5" in a:
        return "Intel Core i5"
    elif "Intel Core i7" in a:
        return "Intel Core i7"
    elif "Intel" in a:
        return "Intel"
    elif "AMD" in a:
        return "AMD"
    else:
        return a

# %%
df["Cpu"]=df["Cpu"].map(cpus)

# %%
df["Cpu"].value_counts()
# Out:
# Intel Core i7                    527
# Intel Core i5                    423
# Intel                            290
# AMD                               62
# Samsung Cortex A72&A53 2.0GHz      1
# Name: Cpu, dtype: int64

# %%
df.drop(df[df["Cpu"]=="Samsung Cortex A72&A53 2.0GHz"].index,inplace=True)

# %%
df["Cpu"].value_counts()
# Out:
# Intel Core i7    527
# Intel Core i5    423
# Intel            290
# AMD               62
# Name: Cpu, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.hist(df["Cpu"],bins=8,color="red")
plt.xlabel("Name of the CPU")
plt.ylabel("Frequency ")
plt.grid()

# %% [markdown]
# #### Company preferred Intel core i7 cpu mostly as it is a more reliable

# %%
sns.barplot(x=df['Cpu'],y=df["Price"])
plt.show()

# %% [markdown]
# ### As Intel I7 is more reliable and gives best performance it also increase cost of the laptop as it is most expensive cpu in the market

# %%
df["Gpu"].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: Gpu, Length: 109, dtype: int64

# %%
def gpus(a):
    if "Intel" in a:
        return "Intel"
    elif "Nvidia" in a:
        return "Nvidia"
    elif "AMD" in a:
        return "AMD"

# %%
df["Gpu"]=df["Gpu"].map(gpus)

# %%
df
# Out:
#      Company            TypeName            Cpu  Ram               Memory  \
# 0      Apple           Ultrabook  Intel Core i5    8            128GB SSD
# 1      Apple           Ultrabook  Intel Core i5    8  128GB Flash Storage
# 2         HP            Notebook  Intel Core i5    8            256GB SSD
# 3      Apple           Ultrabook  Intel Core i7   16            512GB SSD
# 4      Apple           Ultrabook  Intel Core i5    8            256GB SSD
# ...      ...                 ...            ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible  Intel Core i7    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible  Intel Core i7   16            512GB SSD
# 1300  Lenovo            Notebook          Intel    2   64GB Flash Storage
# 1301      HP            Notebook  Intel Core i7    6              1TB HDD
# 1302    Asus            Notebook          Intel    4            500GB HDD
#
#         Gpu       OpSys  Weight        Price  IPS Panel  Touchscreen  \
# ...

# %%
sns.barplot(x=df['Gpu'],y=df["Price"])
plt.show()

# %% [markdown]
# #### Nvidia graphic cards are more expensive than a other graphic cards

# %%
df["OpSys"].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
def os(a):
    if "Windows" in a:
        return "Windows"
    elif "macOS" in a:
        return "Mac"
    elif "Mac OS X" in a:
        return "Mac"
    else:
        return "other/linux/no os"

# %%
df["OpSys"]=df["OpSys"].map(os)

# %%
df["OpSys"].value_counts()
# Out:
# Windows              1125
# other/linux/no os     156
# Mac                    21
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df["Price"])
plt.show()

# %% [markdown]
# #### Mac os is the most expensive oprating system in the laptop market

# %%
df["Memory"].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                37
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df["Memory"]=df["Memory"].str.replace("Hybrid","HDD")

# %%
df.drop(df[df["Memory"]=="32GB Flash Storage"].index,inplace=True)
df.drop(df[df["Memory"]=="64GB Flash Storage"].index,inplace=True)
df.drop(df[df["Memory"]=="256GB Flash Storage"].index,inplace=True)
df.drop(df[df["Memory"]=="16GB Flash Storage"].index,inplace=True)
df.drop(df[df["Memory"]=="128GB Flash Storage"].index,inplace=True)
df.drop(df[df["Memory"]=="512GB Flash Storage"].index,inplace=True)
df.drop(df[df["Memory"]=="64GB Flash Storage +  1TB HDD"].index,inplace=True)

# %%
df["Memory"].value_counts()
# Out:
# 256GB SSD                 412
# 1TB HDD                   223
# 500GB HDD                 132
# 512GB SSD                 118
# 128GB SSD +  1TB HDD       94
# 128GB SSD                  76
# 256GB SSD +  1TB HDD       73
# 2TB HDD                    16
# 1TB SSD                    14
# 512GB SSD +  1TB HDD       14
# 1.0TB HDD                  10
# 256GB SSD +  2TB HDD       10
# 32GB SSD                    6
# 180GB SSD                   5
# 16GB SSD                    3
# 512GB SSD +  2TB HDD        3
# 1TB SSD +  1TB HDD          2
# 256GB SSD +  500GB HDD      2
# 128GB SSD +  2TB HDD        2
# 256GB SSD +  256GB SSD      2
# 512GB SSD +  512GB SSD      1
# 512GB SSD +  256GB SSD      1
# 64GB SSD                    1
# 1TB HDD +  1TB HDD          1
# 32GB HDD                    1
# 128GB HDD                   1
# 240GB SSD                   1
# 8GB SSD                     1
# 508GB HDD                   1
# 512GB SSD +  1.0TB HDD      1
# 256GB SSD +  1.0TB HDD      1
# ...

# %%
df["Memory"].value_counts()
# Out:
# 256GB SSD                 412
# 1TB HDD                   223
# 500GB HDD                 132
# 512GB SSD                 118
# 128GB SSD +  1TB HDD       94
# 128GB SSD                  76
# 256GB SSD +  1TB HDD       73
# 2TB HDD                    16
# 1TB SSD                    14
# 512GB SSD +  1TB HDD       14
# 1.0TB HDD                  10
# 256GB SSD +  2TB HDD       10
# 32GB SSD                    6
# 180GB SSD                   5
# 16GB SSD                    3
# 512GB SSD +  2TB HDD        3
# 1TB SSD +  1TB HDD          2
# 256GB SSD +  500GB HDD      2
# 128GB SSD +  2TB HDD        2
# 256GB SSD +  256GB SSD      2
# 512GB SSD +  512GB SSD      1
# 512GB SSD +  256GB SSD      1
# 64GB SSD                    1
# 1TB HDD +  1TB HDD          1
# 32GB HDD                    1
# 128GB HDD                   1
# 240GB SSD                   1
# 8GB SSD                     1
# 508GB HDD                   1
# 512GB SSD +  1.0TB HDD      1
# 256GB SSD +  1.0TB HDD      1
# ...

# %%
def hdd(a):
    if "HDD" in a:
        if "+" in a:
            a=a.split("+")
            total=0
            for i in a:
                if "HDD" in i:
                    i=i.replace("HDD","")
                    if "GB" in i:
                        i=i.replace("GB","")
                        total=total+float(i)
                    elif "TB" in i:
                        i=i.replace("TB","")
                        i=float(i)*1000
                        total=total+i
            return total
        elif "GB" in a:
            a=a.replace("HDD","")
            a=a.replace("GB","")
            return int(a)
        elif "TB" in a:
            a=a.replace("HDD","")
            a=a.replace("TB","")
            return float(a)*1000
    else:
        return 0

# %%
def ssd(a):
    if "SSD" in a:
        if "+" in a:
            a=a.split("+")
            total=0
            for i in a:
                if "SSD" in i:
                    i=i.replace("SSD","")
                    if "GB" in i:
                        i=i.replace("GB","")
                        total=total+float(i)
                    elif "TB" in i:
                        i=i.replace("TB","")
                        i=float(i)*1000
                        total=total+i
            return total
        elif "GB" in a:
            a=a.replace("SSD","")
            a=a.replace("GB","")
            return int(a)
        elif "TB" in a:
            a=a.replace("SSD","")
            a=a.replace("TB","")
            return float(a)*1000
    else:
        return 0

# %%
df["HDD"]=df["Memory"].map(hdd)

# %%
df["SSD"]=df["Memory"].map(ssd)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1228 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1228 non-null   object
#  1   TypeName     1228 non-null   object
#  2   Cpu          1228 non-null   object
#  3   Ram          1228 non-null   int64
#  4   Memory       1228 non-null   object
#  5   Gpu          1228 non-null   object
#  6   OpSys        1228 non-null   object
#  7   Weight       1228 non-null   float64
#  8   Price        1228 non-null   float64
#  9   IPS Panel    1228 non-null   int64
#  10  Touchscreen  1228 non-null   int64
#  11  PPI          1228 non-null   float64
#  12  HDD          1228 non-null   float64
#  13  SSD          1228 non-null   float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 143.9+ KB

# %%
df.drop("Memory",axis=1,inplace=True)

# %%
df
# Out:
#      Company            TypeName            Cpu  Ram     Gpu  \
# 0      Apple           Ultrabook  Intel Core i5    8   Intel
# 2         HP            Notebook  Intel Core i5    8   Intel
# 3      Apple           Ultrabook  Intel Core i7   16     AMD
# 4      Apple           Ultrabook  Intel Core i5    8   Intel
# 5       Acer            Notebook            AMD    4     AMD
# ...      ...                 ...            ...  ...     ...
# 1297    Asus            Notebook  Intel Core i7    4  Nvidia
# 1298  Lenovo  2 in 1 Convertible  Intel Core i7    4   Intel
# 1299  Lenovo  2 in 1 Convertible  Intel Core i7   16   Intel
# 1301      HP            Notebook  Intel Core i7    6     AMD
# 1302    Asus            Notebook          Intel    4   Intel
#
#                   OpSys  Weight        Price  IPS Panel  Touchscreen  \
# 0                   Mac    1.37   71378.6832          1            0
# 2     other/linux/no os    1.86   30636.0000          0            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1228 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1228 non-null   object
#  1   TypeName     1228 non-null   object
#  2   Cpu          1228 non-null   object
#  3   Ram          1228 non-null   int64
#  4   Gpu          1228 non-null   object
#  5   OpSys        1228 non-null   object
#  6   Weight       1228 non-null   float64
#  7   Price        1228 non-null   float64
#  8   IPS Panel    1228 non-null   int64
#  9   Touchscreen  1228 non-null   int64
#  10  PPI          1228 non-null   float64
#  11  HDD          1228 non-null   float64
#  12  SSD          1228 non-null   float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 134.3+ KB

# %%
sns.pairplot(df)

# %%
x=df.drop("Price",axis=1)
y=df["Price"]

# %%
from scipy.stats import skew

# %%
col=x.select_dtypes(["int64","float64"]).columns

# %%
x[col]
# Out:
#       Ram  Weight  IPS Panel  Touchscreen         PPI     HDD    SSD
# 0       8    1.37          1            0  226.983005     0.0  128.0
# 2       8    1.86          0            0  141.211998     0.0  256.0
# 3      16    1.83          1            0  220.534624     0.0  512.0
# 4       8    1.37          1            0  226.983005     0.0  256.0
# 5       4    2.10          0            0  100.454670   500.0    0.0
# ...   ...     ...        ...          ...         ...     ...    ...
# 1297    4    2.20          0            0  100.454670   500.0    0.0
# 1298    4    1.80          1            1  157.350512     0.0  128.0
# 1299   16    1.30          1            1  276.053530     0.0  512.0
# 1301    6    2.19          0            0  100.454670  1000.0    0.0
# 1302    4    2.20          0            0  100.454670   500.0    0.0
#
# [1228 rows x 7 columns]

# %%
for i in x[col]:
    print(i)
    print(skew(x[i]))
    sns.distplot(x[i])
    plt.show()
# Out:
# Ram
# 2.7145654888506687
# Weight
# 1.1725992799851306
# IPS Panel
# 0.9792383332742227
# Touchscreen
# 2.007728542173442
# PPI
# 2.058268360909137
# HDD
# 0.7621339750675005
# SSD
# 1.3329610315578104

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_9d17e_row0_col0, #T_9d17e_row1_col1, #T_9d17e_row2_col2, #T_9d17e_row3_col3, #T_9d17e_row4_col4, #T_9d17e_row5_col5, #T_9d17e_row6_col6, #T_9d17e_row7_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9d17e_row0_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_9d17e_row0_col2 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_9d17e_row0_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_9d17e_row0_col4 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_9d17e_row0_col5 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_9d17e_row0_col6 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_9d17e_row0_col7 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_9d17e_row1_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_9d17e_row1_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_9d17e_row1_col3 {
#   background-color: #ede8f3;
# ...

# %% [markdown]
# #### All the columns which was showing skewness has good correlation with the target column thats why I did not Remove the skewness of those column

# %%
cols=df.select_dtypes(object).columns

# %%
from sklearn.preprocessing import OrdinalEncoder
oh=OrdinalEncoder()
df[cols]=oh.fit_transform(df[cols])

# %% [markdown]
# ### Splitting the data

# %%
x=df.drop("Price",axis=1)
y=np.log(df["Price"])

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
x.iloc[:,:]=sd.fit_transform(x.iloc[:,:])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %% [markdown]
# ### 1 - Predicting the data using Linear egression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
from sklearn.metrics import r2_score
r2_score(ytest,ypred)
# Out:
# 0.7445752870450626

# %%
plt.scatter(ytest,ypred)
plt.show()

# %%
sns.distplot(ytest-ypred)
plt.show()

# %% [markdown]
# ### we have achieved an average accuracy of 75 % which isnt that great.

# %%
lr.score(xtrain,ytrain)
# Out:
# 0.7536198895293524

# %%
lr.score(xtest,ytest)
# Out:
# 0.7445752870450626

# %% [markdown]
# ### Evaluate the model(Errors)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print("MAE:",mean_absolute_error(ytest,ypred))
print("MSE:",mean_squared_error(ytest,ypred))
print("RMSE:",np.sqrt(mean_squared_error(ytest,ypred)))
# Out:
# MAE: 0.229055253755423
# MSE: 0.08475218494297915
# RMSE: 0.2911222852049962

# %% [markdown]
# ### From the above values, we can conclude that the model is not over fitting. However it a very low accuracy

# %% [markdown]
# ## 2- Predicting the data using KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(xtrain,ytrain)
ypred=knn.predict(xtest)

# %%
r2_score(ytest,ypred)
# Out:
# 0.8067564955091571

# %% [markdown]
# ## we have achieved an average accuracy of 80 % . Lets see if we can increase this accuracy by hyper tuning

# %%
for i in range(2,31):
    knn=KNeighborsRegressor(n_neighbors=i)
    knn.fit(xtrain,ytrain)
    ypred=knn.predict(xtest)
    acc=r2_score(ytest,ypred)
    print(acc)
# Out:
# 0.7920722682254493
# 0.8165988753560584
# 0.8226767446757652
# 0.8067564955091571
# 0.8046525264261745
# 0.8019255826266498
# 0.7996785955136816
# 0.798438828105086
# 0.7991150699699835
# 0.7939035073432666
# 0.7905699570853472
# 0.7928732722787221
# 0.7878363440636786
# 0.7822994243233812
# 0.7803402317953761
# 0.7799922355915818
# 0.7777197673334382
# 0.7719954437437475
# 0.7701313021532465
# 0.771381115161899
# 0.7694702000653062
# 0.7684833341612406
# 0.7681799670950943
# 0.7657039481882931
# 0.7658591463416227
# 0.7654875051831708
# 0.7643067150475567
# 0.7628026909870868
# 0.7612340947025007

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=4)
knn.fit(xtrain,ytrain)
ypred=knn.predict(xtest)

# %%
r2_score(ytest,ypred)
# Out:
# 0.8226767446757652

# %%
knn.score(xtrain,ytrain)
# Out:
# 0.8804404291236759

# %%
knn.score(xtest,ytest)
# Out:
# 0.8226767446757652

# %% [markdown]
# ## After hyper tuning we have achieved an average accuracy of 82 % .From the above values, we can conclude that the model is little overfit.

# %% [markdown]
# ## 3Regularization

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
train=lr.score(xtrain,ytrain)
test=lr.score(xtest,ytest)
print(train,test)
# Out:
# 0.7536198895293524 0.7445752870450626

# %% [markdown]
# ## Ridge(L2)

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
l2=Ridge(alpha=5)
l2.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=5)

# %%
train=l2.score(xtrain,ytrain)
test=l2.score(xtest,ytest)
print(train,test)
# Out:
# 0.753612252329159 0.7449094774112854

# %% [markdown]
# ### At default value of alpha we were getting difference of 1% in training and testing score lets see we can reduse that difference

# %% [markdown]
# ## Hypertunning alpha

# %%
for i in range(101,151):
    l2=Ridge(alpha=i)
    l2.fit(xtrain,ytrain)
    test=l2.score(xtest,ytest)
    print(f"lambda {i} testscore {test}")
# Out:
# lambda 101 testscore 0.748145152944955
# lambda 102 testscore 0.7481537943335265
# lambda 103 testscore 0.7481620189318473
# lambda 104 testscore 0.7481698290891715
# lambda 105 testscore 0.7481772271337237
# lambda 106 testscore 0.7481842153729715
# lambda 107 testscore 0.748190796093898
# lambda 108 testscore 0.7481969715632643
# lambda 109 testscore 0.7482027440278726
# lambda 110 testscore 0.7482081157148222
# lambda 111 testscore 0.7482130888317612
# lambda 112 testscore 0.7482176655671356
# lambda 113 testscore 0.7482218480904329
# lambda 114 testscore 0.7482256385524214
# lambda 115 testscore 0.7482290390853878
# lambda 116 testscore 0.7482320518033687
# lambda 117 testscore 0.7482346788023782
# lambda 118 testscore 0.7482369221606342
# lambda 119 testscore 0.7482387839387783
# lambda 120 testscore 0.7482402661800942
# lambda 121 testscore 0.7482413709107214
# lambda 122 testscore 0.7482421001398649
# lambda 123 testscore 0.7482424558600043
# ...

# %%
l2=Ridge(alpha=139)
l2.fit(xtrain,ytrain)
train=l2.score(xtrain,ytrain)
test=l2.score(xtest,ytest)
print(train,test)
# Out:
# 0.7493821974474897 0.7481989142309197

# %% [markdown]
# ### After hypertuning  we got best value of alpha which was giving almost same training and testing score

# %% [markdown]
# ## Hypertuning using lasso

# %%
for i in range(1,51):
    l1=Lasso(alpha=i)
    l1.fit(xtrain,ytrain)
    test=l1.score(xtest,ytest)
    print(f"lambda {i} testscore {test}")
# Out:
# lambda 1 testscore -0.0007730270552916974
# lambda 2 testscore -0.0007730270552916974
# lambda 3 testscore -0.0007730270552916974
# lambda 4 testscore -0.0007730270552916974
# lambda 5 testscore -0.0007730270552916974
# lambda 6 testscore -0.0007730270552916974
# lambda 7 testscore -0.0007730270552916974
# lambda 8 testscore -0.0007730270552916974
# lambda 9 testscore -0.0007730270552916974
# lambda 10 testscore -0.0007730270552916974
# lambda 11 testscore -0.0007730270552916974
# lambda 12 testscore -0.0007730270552916974
# lambda 13 testscore -0.0007730270552916974
# lambda 14 testscore -0.0007730270552916974
# lambda 15 testscore -0.0007730270552916974
# lambda 16 testscore -0.0007730270552916974
# lambda 17 testscore -0.0007730270552916974
# lambda 18 testscore -0.0007730270552916974
# lambda 19 testscore -0.0007730270552916974
# lambda 20 testscore -0.0007730270552916974
# lambda 21 testscore -0.0007730270552916974
# lambda 22 testscore -0.0007730270552916974
# ...

# %% [markdown]
# #### we can not use lasso as it was giving very low accuracy

# %% [markdown]
# ## cross validation techniques

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
kf=KFold(n_splits=5)
csv=cross_val_score(l2,x,y,cv=kf)
print(csv)
print(csv.mean())
# Out:
# [0.76938933 0.73886911 0.74086116 0.60730097 0.73791029]
# 0.7188661739908964

# %% [markdown]
# #### After using the cross validation techniques with l2 we got 71% accuracy which is very less

# %% [markdown]
# ## 4-SVM

# %%
from sklearn.svm import SVR
svm=SVR()

# %%
def my_model(model):
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    print(r2_score(ytest,ypred))
    return model

# %%
my_model(svm)
# Out:
# 0.8545432149681089
# SVR()

# %% [markdown]
# #### Before hypertuning svm is giving us 85% accuracy which is quite good still lets see we can increase it by hyperturning

# %% [markdown]
# ### Hypertuning SVM model using different kernals

# %%
svm=SVR(kernel="linear")
my_model(svm)

# %%
svm=SVR(kernel="poly")
my_model(svm)

# %%
svm=SVR(kernel="sigmoid")
my_model(svm)

# %% [markdown]
# ## As we can see default kernal was giving us best accuracy

# %% [markdown]
# ## GridSearchCV`

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={"C":[1,10],"gamma":[1,10],"kernel":["rbf"]}

# %%
gs=GridSearchCV(svm,param_grid,verbose=3)
gs.fit(xtrain,ytrain)
ypred=gs.predict(xtest)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.576 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.559 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.528 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.556 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.603 total time=   0.0s
# [CV 1/5] END .........C=1, gamma=10, kernel=rbf;, score=0.249 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=10, kernel=rbf;, score=0.225 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=10, kernel=rbf;, score=0.204 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=10, kernel=rbf;, score=0.234 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=10, kernel=rbf;, score=0.242 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.568 total time=   0.0s
# ...

# %%
gs.best_estimator_
# Out:
# SVR(C=1, gamma=1)

# %%
svc=gs.best_estimator_
svc.fit(xtrain,ytrain)
ypred=svc.predict(xtest)

# %%
r2_score(ytest,ypred)
# Out:
# 0.6647834137017198

# %% [markdown]
# #### After using GridSearchCV with best values of c and Gamma we got 66% accuracy which not acceptable at all

# %% [markdown]
# ## 5-Decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# %%
dt=DecisionTreeRegressor()

# %%
def my_model(model):
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    print("Accuracy",r2_score(ytest,ypred))
    print("Traning score",model.score(xtrain,ytrain))
    print("testing score",model.score(xtest,ytest))
    return model

# %%
my_model(dt)
# Out:
# Accuracy 0.7607588209989982
# Traning score 0.9965244475170659
# testing score 0.7607588209989982
# DecisionTreeRegressor()

# %% [markdown]
# #### After using DT we got 76% accuracy with the overfit model lets try to remove overfiting by hypertuning the DT

# %%
fig,ax=plt.subplots(figsize=(25,10))
chart=tree.plot_tree(dt,max_depth=5,feature_names=x.columns,filled=True,fontsize=10)
plt.savefig("laptoptree.jpg")

# %% [markdown]
# ### Hypertuning DT

# %% [markdown]
# ### 1.max_depth

# %%
for i in range(301,401):
    dt2=DecisionTreeRegressor(max_depth=i)
    my_model(dt2)
# Out:
# Accuracy 0.770226520348628
# Traning score 0.9965244475170659
# testing score 0.770226520348628
# Accuracy 0.7720889269084246
# Traning score 0.9965244475170659
# testing score 0.7720889269084246
# Accuracy 0.7582901481921552
# Traning score 0.9965244475170659
# testing score 0.7582901481921552
# Accuracy 0.7660320308446356
# Traning score 0.9965244475170659
# testing score 0.7660320308446356
# Accuracy 0.757507312422727
# Traning score 0.9965244475170659
# testing score 0.757507312422727
# Accuracy 0.7573234810574287
# Traning score 0.9965244475170659
# testing score 0.7573234810574287
# Accuracy 0.7635476230327033
# Traning score 0.9965244475170659
# testing score 0.7635476230327033
# Accuracy 0.7708231132590119
# Traning score 0.9965244475170659
# testing score 0.7708231132590119
# Accuracy 0.7610907272498185
# Traning score 0.9965244475170659
# testing score 0.7610907272498185
# Accuracy 0.7663945691898405
# Traning score 0.9965244475170659
# testing score 0.7663945691898405
# ...

# %%
dt3=DecisionTreeRegressor(max_depth=191)
my_model(dt3)
# Out:
# Accuracy 0.7558210546177193
# Traning score 0.9965244475170659
# testing score 0.7558210546177193
# DecisionTreeRegressor(max_depth=191)

# %% [markdown]
# ### 2.min_sample_split

# %%
for i in range(151,200):
    dt4=DecisionTreeRegressor(min_samples_split=i)
    print(i)
    my_model(dt4)
# Out:
# 151
# Accuracy 0.7491814996615892
# Traning score 0.7657063397135372
# testing score 0.7491814996615892
# 152
# Accuracy 0.745616077733919
# Traning score 0.7516607905140941
# testing score 0.745616077733919
# 153
# Accuracy 0.7456160777339191
# Traning score 0.7516607905140941
# testing score 0.7456160777339191
# 154
# Accuracy 0.7456160777339196
# Traning score 0.7516607905140941
# testing score 0.7456160777339196
# 155
# Accuracy 0.7456160777339189
# Traning score 0.7516607905140941
# testing score 0.7456160777339189
# 156
# Accuracy 0.7456160777339187
# Traning score 0.7516607905140941
# testing score 0.7456160777339187
# 157
# Accuracy 0.7456160777339194
# Traning score 0.7516607905140941
# testing score 0.7456160777339194
# 158
# Accuracy 0.7304278921584899
# Traning score 0.7423707584509812
# testing score 0.7304278921584899
# 159
# Accuracy 0.7304278921584904
# Traning score 0.7423707584509813
# testing score 0.7304278921584904
# 160
# Accuracy 0.7304278921584908
# ...

# %%
dt5=DecisionTreeRegressor(min_samples_split=152)
my_model(dt5)
# Out:
# Accuracy 0.7456160777339189
# Traning score 0.7516607905140941
# testing score 0.7456160777339189
# DecisionTreeRegressor(min_samples_split=152)

# %% [markdown]
# ### 3.min_sample_leaf

# %%
for i in range(1,51):
    dt6=DecisionTreeRegressor(min_samples_leaf=i)
    print(i)
    my_model(dt6)
# Out:
# 1
# Accuracy 0.7608281917128876
# Traning score 0.9965244475170659
# testing score 0.7608281917128876
# 2
# Accuracy 0.7662030492238159
# Traning score 0.9647428338232905
# testing score 0.7662030492238159
# 3
# Accuracy 0.772655299312205
# Traning score 0.9380973592378596
# testing score 0.772655299312205
# 4
# Accuracy 0.7886794890986243
# Traning score 0.9259994039312893
# testing score 0.7886794890986243
# 5
# Accuracy 0.7804445022171429
# Traning score 0.9099395508710664
# testing score 0.7804445022171429
# 6
# Accuracy 0.7709601557239762
# Traning score 0.8977918678476386
# testing score 0.7709601557239762
# 7
# Accuracy 0.7757927974524736
# Traning score 0.8836425981831431
# testing score 0.7757927974524736
# 8
# Accuracy 0.7784343363087398
# Traning score 0.8778389410444456
# testing score 0.7784343363087398
# 9
# Accuracy 0.7825872376745335
# Traning score 0.8716821800230212
# testing score 0.7825872376745335
# 10
# Accuracy 0.7832835532684885
# ...

# %%
dt7=DecisionTreeRegressor(min_samples_leaf=40)
my_model(dt7)
# Out:
# Accuracy 0.7532850136946696
# Traning score 0.7594030569549506
# testing score 0.7532850136946696
# DecisionTreeRegressor(min_samples_leaf=40)

# %% [markdown]
# ### After hypertuning the DT we got best accuracy using min_sample_leaf method which also removed the overfiting with 40 leaf and 75% accuracy

# %% [markdown]
# ### Bagging

# %%
dt=DecisionTreeRegressor()
li=LinearRegression()
svm=SVR()

# %%
from sklearn.ensemble import BaggingRegressor
bl=BaggingRegressor(LinearRegression())
bl.fit(xtrain,ytrain)
ypred=bl.predict(xtest)

# %%
r2_score(ytest,ypred)
# Out:
# 0.7454197628007052

# %%
bs=BaggingRegressor(SVR())
bs.fit(xtrain,ytrain)
ypred=bs.predict(xtest)

# %%
r2_score(ytest,ypred)
# Out:
# 0.8535173392778208

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
rc=RandomForestRegressor()
rc.fit(xtrain,ytrain)
ypred=rc.predict(xtest)
print(r2_score(ytest,ypred))
# Out:
# 0.8517761040602368

# %% [markdown]
# ### Voting

# %%
model=[]
model.append(("lr",LinearRegression()))
model.append(("dt",DecisionTreeRegressor()))
model.append(("svm",SVR()))

# %%
from sklearn.ensemble import VotingRegressor
vc=VotingRegressor(estimators=model)
vc.fit(xtrain,ytrain)
ypred=vc.predict(xtest)
print(r2_score(ytest,ypred))
# Out:
# 0.8443659141330404

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor
ab=AdaBoostRegressor()
ab.fit(xtrain,ytrain)
ypred=ab.predict(xtest)
print(r2_score(ytest,ypred))
# Out:
# 0.8144292353483972

# %% [markdown]
# ## GradientBoost

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb=GradientBoostingRegressor()
gb.fit(xtrain,ytrain)
ypred=gb.predict(xtest)
print(r2_score(ytest,ypred))
# Out:
# 0.860845936917985

# %% [markdown]
# ### xgboost

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor()
xgb.fit(xtrain,ytrain)
ypred=xgb.predict(xtest)
print(r2_score(ytest,ypred))
# Out:
# 0.8721201957356287

# %% [markdown]
# #### After applying all the Ensemble learning algorithms we got the best accuracy 87% with  extreme gradient boosting (xgboost).

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Based on the above accuracy scores, we should go ahead with extreme gradient boosting (xgboost).

# %% [markdown]
# #### Entering New value for prediction

# %%
d={"Company":"HP","TypeName":"Ultrabook","Cpu":"Intel Core i5","Ram":16,"Gpu":"AMD","OpSys":"Windows","Weight":2.10,"IPS Panel":1,"Touchscreen":1,"PPI":220.534624,"HDD":500,"SSD":500}

# %%
nd=pd.DataFrame(d,index=[1])

# %%
nd
# Out:
#   Company   TypeName            Cpu  Ram  Gpu    OpSys  Weight  IPS Panel  \
# 1      HP  Ultrabook  Intel Core i5   16  AMD  Windows     2.1          1
#
#    Touchscreen         PPI  HDD  SSD
# 1            1  220.534624  500  500

# %%
cols=nd.select_dtypes(object).columns

# %%
nd[cols]=oh.transform(nd[cols])

# %%
nd
# Out:
#    Company  TypeName  Cpu  Ram  Gpu  OpSys  Weight  IPS Panel  Touchscreen  \
# 1      6.0       4.0  2.0   16  0.0    1.0     2.1          1            1
#
#           PPI  HDD  SSD
# 1  220.534624  500  500

# %%
nd.iloc[:,:]=sd.transform(nd.iloc[:,:])

# %%
newpred=np.exp(xgb.predict(nd))

# %%
newpred
# Out:
# array([142247.12], dtype=float32)
